# %% [markdown]
# Adapted from https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %%
import numpy as np
import pandas as pd
from keras import Sequential
from keras.layers import LSTM, Dense, TimeDistributed
from pandas import read_csv
from datetime import datetime
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import mean_squared_error
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# This is a dataset that reports on the weather and the 
# level of pollution each hour for five years at the US 
# embassy in Beijing, China
# 
# No: row number
# year: year of data in this row
# month: month of data in this row
# day: day of data in this row
# hour: hour of data in this row
# pm2.5: PM2.5 concentration
# DEWP: Dew Point
# TEMP: Temperature
# PRES: Pressure
# cbwd: Combined wind direction
# Iws: Cumulated wind speed
# Is: Cumulated hours of snow
# Ir: Cumulated hours of rain

# %%
# load data
def parse(x):
    return datetime.strptime(x, '%Y %m %d %H')
dataset = read_csv('raw.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
dataset.drop('No', axis=1, inplace=True)
# manually specify column names
dataset.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
dataset.index.name = 'date'
# mark all NA values with 0
dataset['pollution'].fillna(0, inplace=True)
# drop the first 24 hours
dataset = dataset[24:]
# summarize first 5 rows
print(dataset.head(5))
# save to file
dataset.to_csv('pollution.csv')
# Out:
#                      pollution  dew  temp   press wnd_dir  wnd_spd  snow  rain
# date
# 2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79     0     0
# 2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68     0     0
# 2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57     0     0
# 2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36     1     0
# 2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25     2     0

# %%
# load dataset
dataset = read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3, 5, 6, 7]
i = 1
# plot each column
pyplot.figure()
for group in groups:
        pyplot.subplot(len(groups), 1, i)
        pyplot.plot(values[:, group])
        pyplot.title(dataset.columns[group], y=0.5, loc='right')
        i += 1
pyplot.show()

# %%
# Function to slice the data into:
# input: [0:n_in] steps
# output: [0:n_out] steps


def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out+1):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset
dataset = read_csv('pollution.csv', header=0, index_col=0)
values = dataset.values
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# specify the number of lag hours
n_hours = 20
n_features = 8

# frame as supervised learning
reframed = series_to_supervised(scaled, n_hours, n_hours)
print(reframed.shape)
# Out:
# (43760, 328)

# %%
# split into train and test sets


values = reframed.values
n_train_hours = 365 * 24
train = values[:n_train_hours, :]
test = values[n_train_hours:, :]
# split into input and outputs
n_obs = n_hours * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_obs]
test_X, test_y = test[:, :n_obs], test[:, -n_obs]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
train_y = train_X.reshape((train_X.shape[0], n_hours, n_features))
train_y = train_y[:,:,-n_features]
train_y = np.expand_dims(train_y,2)
test_y = test_X.reshape((test_X.shape[0], n_hours, n_features))
test_y = test_y[:,:,-n_features]
test_y = np.expand_dims(test_y,2)
train_X = train_X[:,:,1:]
test_X = test_X[:,:,1:]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (8760, 20, 7) (8760, 20, 1) (35000, 20, 7) (35000, 20, 1)

# %%
 
# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]),return_sequences=True))
model.add(TimeDistributed(Dense(1))) # Repeats the dense layers overtop the LSTM outputs
model.compile(loss='mse', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=25, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()
# Out:
# WARNING:tensorflow:From c:\users\jschne\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\jschne\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 8760 samples, validate on 35000 samples
# Epoch 1/25
#  - 3s - loss: 0.0081 - val_loss: 0.0208
# Epoch 2/25
#  - 2s - loss: 0.0067 - val_loss: 0.0270
# Epoch 3/25
#  - 2s - loss: 0.0064 - val_loss: 0.0310
# Epoch 4/25
#  - 2s - loss: 0.0062 - val_loss: 0.0335
# Epoch 5/25
#  - 2s - loss: 0.0062 - val_loss: 0.0351
# Epoch 6/25
#  - 2s - loss: 0.0062 - val_loss: 0.0364
# Epoch 7/25
#  - 2s - loss: 0.0062 - val_loss: 0.0375
# Epoch 8/25
#  - 2s - loss: 0.0063 - val_loss: 0.0385
# Epoch 9/25
#  - 2s - loss: 0.0063 - val_loss: 0.0393
# Epoch 10/25
#  - 2s - loss: 0.0064 - val_loss: 0.0394
# Epoch 11/25
#  - 2s - loss: 0.0065 - val_loss: 0.0391
# Epoch 12/25
#  - 2s - loss: 0.0066 - val_loss: 0.0382
# Epoch 13/25
#  - 2s - loss: 0.0068 - val_loss: 0.0367
# Epoch 14/25
#  - 2s - loss: 0.0069 - val_loss: 0.0348
# Epoch 15/25
#  - 3s - loss: 0.0071 - val_loss: 0.0317
# Epoch 16/25
#  - 3s - loss: 0.0073 - val_loss: 0.0272
# Epoch 17/25
#  - 3s - loss: 0.0074 - val_loss: 0.0242
# Epoch 18/25
#  - 3s - loss: 0.0075 - val_loss: 0.0211
# Epoch 19/25
#  - 3s - loss: 0.0075 - val_loss: 0.0194
# Epoch 20/25
#  - 3s - loss: 0.0075 - val_loss: 0.0169
# Epoch 21/25
#  - 3s - loss: 0.0075 - val_loss: 0.0157
# Epoch 22/25
#  - 3s - loss: 0.0075 - val_loss: 0.0143
# Epoch 23/25
#  - 3s - loss: 0.0074 - val_loss: 0.0139
# Epoch 24/25
#  - 3s - loss: 0.0073 - val_loss: 0.0135
# Epoch 25/25
#  - 3s - loss: 0.0072 - val_loss: 0.0135

# %%
# make a prediction
yhat = model.predict(test_X)

# calculate RMSE
rmse= np.zeros((yhat.shape[0],1))
for i in range(yhat.shape[0]):
    rmse[i] = np.sqrt(mean_squared_error(test_y[i,:], yhat[i,:]))
print('Test RMSE: %.3f' % np.mean(rmse))
# Out:
# Test RMSE: 0.101

# %%
# 
pyplot.figure()
pyplot.plot(yhat[900,:])
pyplot.plot(test_y[900,:])

# %%
dif=test_y-yhat
dif=np.mean(dif,0)
sdif=np.std(test_y-yhat,0)
pyplot.figure()
pyplot.errorbar(range(20),dif,sdif)
# Out:
# <ErrorbarContainer object of 3 artists>
